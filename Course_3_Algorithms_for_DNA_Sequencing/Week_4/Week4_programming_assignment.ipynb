# %%
# !wget https://d28rh4a8wq0iu5.cloudfront.net/ads1/data/ads1_week4_reads.fq

# %%
import itertools

overlap_cache = {} 

def overlap(a, b, min_length=3):
    """ Return length of longest suffix of 'a' matching
        a prefix of 'b' that is at least 'min_length'
        characters long.  If no such overlap exists,
        return 0. """
    start = 0  # start all the way at the left
    while True:
        start = a.find(b[:min_length], start)  # look for b's suffx in a
        if start == -1:  # no more occurrences to right
            return 0
        # found occurrence; check for full suffix/prefix match
        if b.startswith(a[start:]):
            return len(a)-start
        start += 1  # move just past previous match



def scs(ss):
    """ Returns shortest common superstring of given
        strings, which must be the same length """
    shortest_sup = None
    for ssperm in itertools.permutations(ss):
        sup = ssperm[0]  # superstring starts as first string
        for i in range(len(ss)-1):
            # overlap adjacent strings A and B in the permutation
            olen = overlap(ssperm[i], ssperm[i+1], min_length=1)
            # add non-overlapping portion of B to superstring
            sup += ssperm[i+1][olen:]
        if shortest_sup is None or len(sup) < len(shortest_sup):
            shortest_sup = sup  # found shorter superstring
    return shortest_sup  # return shortest

def scs_list(ss):
    """ Returns the alphebeticaly sorted list of shortest common superstrings of given strings, which must be the same length """
    shortest_sup = []
    shortest_length = 0
    for ssperm in itertools.permutations(ss):
        sup = ssperm[0]  # superstring starts as first string
        for i in range(len(ss)-1):
            # overlap adjacent strings A and B in the permutation
            olen = overlap(ssperm[i], ssperm[i+1], min_length=1)
            # add non-overlapping portion of B to superstring
            sup += ssperm[i+1][olen:]
        if shortest_length == 0:
            shortest_sup.append(sup)
            shortest_length = len(sup)
        elif len(sup) < shortest_length:
            shortest_length = len(sup)
            shortest_sup = [sup]
        elif len(sup) == shortest_length:
            shortest_sup.append(sup)
        else:
            #simply ignore and move on
            None
    return sorted(shortest_sup)

def readFastq(filename):
    sequences = []
    qualities = []
    with open(filename) as fh:
        while True:
            fh.readline()  # skip name line
            seq = fh.readline().rstrip()  # read base sequence
            fh.readline()  # skip placeholder line
            qual = fh.readline().rstrip() # base quality line
            if len(seq) == 0:
                break
            #All the reads are the same length (100 bases) 
            assert len(seq) == 100
            sequences.append(seq)
            qualities.append(qual)
    return sequences, qualities


def pick_maximal_overlap(reads, k):
    """ Return a pair of reads from the list with a
        maximal suffix/prefix overlap >= k.  Returns
        overlap length 0 if there are no such overlaps."""
    reada, readb = None, None
    best_olen = 0

    for a, b in itertools.permutations(reads, 2):
        
        if (a,b) in overlap_cache.keys() and overlap_cache[(a,b)] >= k:
            overlap_len = overlap_cache[(a,b)]
            return a, b, overlap_len
        else:
            olen = overlap(a, b, min_length=k)
            if olen > best_olen:
                reada, readb = a, b
                best_olen = olen
                overlap_cache[(a,b)]=best_olen

    return reada, readb, best_olen

def greedy_scs(reads, k):
    """ Greedy shortest-common-superstring merge.
        Repeat until no edges (overlaps of length >= k)
        remain. """
    lenCacheBefore = len(overlap_cache)
    read_a, read_b, olen = pick_maximal_overlap(reads, k)

    while olen > 0:
        reads.remove(read_a)
        reads.remove(read_b)
        reads.append(read_a + read_b[olen:])
        
        read_a, read_b, olen = pick_maximal_overlap(reads, k)
    
    lenCacheAfter = len(overlap_cache)

    return ''.join(reads)


# question 1
input_str = ['CCT', 'CTT', 'TGC', 'TGG', 'GAT', 'ATT']
scs1 = scs(input_str)
print(f'Question 1: {len(scs1)}')


# question 2
shortest = scs_list( ['CCT', 'CTT', 'TGC', 'TGG', 'GAT', 'ATT'] )
print(f'Question 2: {len(shortest)}')

# question 3 & 4
def count_a_and_t():
    
    reads, qualities = readFastq('ads1_week4_reads.fq')
    
    print('Round 1')
    for i in range (30, 100):
        print(f'Working on {i}')
        result = greedy_scs(list(reads), i)  # make copy of reads
        print(f'Found result {len(result)} bases long where k={i}')

        # virus genome length is 15894
        if len(result) == 15894:
            print(f"Question 3: {result.count('A')}")
            print(f"Question 4: {result.count('T')}")
            return

    print('Round 2')
    for i in range (30, 1, -1):
        print(f'Working on {i}')
        result = greedy_scs(list(reads), i)  # make copy of reads
        print(f'Found result {len(result)} bases long where k={i}')

        # virus genome length is 15894
        if len(result) == 15894:
            print(f"Question 3: {result.count('A')}")
            print(f"Question 4: {result.count('T')}")
            return
        
def main():
    count_a_and_t()
    
if __name__ == '__main__':
    main()
# Out:
# Question 1: 11
# Question 2: 4
# Round 1
# Working on 30
# Found result 16867 bases long where k=30
# Working on 31
# Found result 17196 bases long where k=31
# Working on 32
# Found result 18132 bases long where k=32
# Working on 33
# Found result 17992 bases long where k=33
# Working on 34
# Found result 18259 bases long where k=34
# Working on 35
# Found result 16325 bases long where k=35
# Working on 36
# Found result 17484 bases long where k=36
# Working on 37
# Found result 17974 bases long where k=37
# Working on 38
# Found result 17643 bases long where k=38
# Working on 39
# Found result 16781 bases long where k=39
# Working on 40
# Found result 17761 bases long where k=40
# Working on 41
# Found result 18010 bases long where k=41
# Working on 42
# Found result 17262 bases long where k=42
# Working on 43
# Found result 18860 bases long where k=43
# Working on 44
# Found result 17852 bases long where k=44
# Working on 45
# Found result 17094 bases long where k=45
# Working on 46
# Found result 18120 bases long where k=46
# Working on 47
# Found result 19077 bases long where k=47
# Working on 48
# Found result 17723 bases long where k=48
# Working on 49
# Found result 17434 bases long where k=49
# Working on 50
# Found result 17981 bases long where k=50
# Working on 51
# Found result 18743 bases long where k=51
# Working on 52
# Found result 19151 bases long where k=52
# Working on 53
# Found result 17524 bases long where k=53
# Working on 54
# Found result 17862 bases long where k=54
# Working on 55
# Found result 18884 bases long where k=55
# Working on 56
# Found result 18446 bases long where k=56
# Working on 57
# Found result 17714 bases long where k=57
# Working on 58
# Found result 19551 bases long where k=58
# Working on 59
# Found result 18739 bases long where k=59
# Working on 60
# Found result 19129 bases long where k=60
# Working on 61
# Found result 19966 bases long where k=61
# Working on 62
# Found result 19240 bases long where k=62
# Working on 63
# Found result 19917 bases long where k=63
# Working on 64
# Found result 21627 bases long where k=64
# Working on 65
# Found result 21884 bases long where k=65
# Working on 66
# Found result 20801 bases long where k=66
# Working on 67
# Found result 22158 bases long where k=67
# Working on 68
# Found result 21944 bases long where k=68
# Working on 69
# Found result 23018 bases long where k=69
# Working on 70
# Found result 23148 bases long where k=70
# Working on 71
# Found result 22694 bases long where k=71
# Working on 72
# Found result 23300 bases long where k=72
# Working on 73
# Found result 24700 bases long where k=73
# Working on 74
# Found result 26368 bases long where k=74
# Working on 75
# Found result 27479 bases long where k=75
# Working on 76
# Found result 27564 bases long where k=76
# Working on 77
# Found result 28756 bases long where k=77
# Working on 78
# Found result 30254 bases long where k=78
# Working on 79
# Found result 31949 bases long where k=79
# Working on 80
# Found result 33797 bases long where k=80
# Working on 81
# Found result 34842 bases long where k=81
# Working on 82
# Found result 36682 bases long where k=82
# Working on 83
# Found result 38991 bases long where k=83
# Working on 84
# Found result 41746 bases long where k=84
# Working on 85
# Found result 43880 bases long where k=85
# Working on 86
# Found result 46445 bases long where k=86
# Working on 87
# Found result 50237 bases long where k=87
# Working on 88
# Found result 56025 bases long where k=88
# Working on 89
# Found result 60967 bases long where k=89
# Working on 90
# Found result 66977 bases long where k=90
# Working on 91
# Found result 73214 bases long where k=91
# Working on 92
# Found result 79307 bases long where k=92
# Working on 93
# Found result 85874 bases long where k=93
# Working on 94
# Found result 93966 bases long where k=94
# Working on 95
# Found result 105222 bases long where k=95
# Working on 96
# Found result 115460 bases long where k=96
# Working on 97
# Found result 129146 bases long where k=97
# Working on 98
# Found result 144038 bases long where k=98
# Working on 99
# Found result 163732 bases long where k=99
# Round 2
# Working on 30
# Found result 17243 bases long where k=30
# Working on 29
# Found result 16560 bases long where k=29
# Working on 28
# Found result 18001 bases long where k=28
# Working on 27
# Found result 17488 bases long where k=27
# Working on 26
# Found result 17845 bases long where k=26
# Working on 25
# Found result 16590 bases long where k=25
# Working on 24
# Found result 16755 bases long where k=24
# Working on 23
# Found result 18408 bases long where k=23
# Working on 22
# Found result 17779 bases long where k=22
# Working on 21
# Found result 16993 bases long where k=21
# Working on 20
# Found result 16750 bases long where k=20
# Working on 19
# Found result 16172 bases long where k=19
# Working on 18
# Found result 16364 bases long where k=18
# Working on 17
# Found result 16005 bases long where k=17
# Working on 16
# Found result 16578 bases long where k=16
# Working on 15
# Found result 16257 bases long where k=15
# Working on 14
# Found result 16218 bases long where k=14
# Working on 13
# Found result 17832 bases long where k=13
# Working on 12
# Found result 15894 bases long where k=12
# Question 3: 4633
# Question 4: 3723
